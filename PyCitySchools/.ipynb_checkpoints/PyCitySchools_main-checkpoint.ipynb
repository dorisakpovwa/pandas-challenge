# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load 
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# %%
# checking school data
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
# checking student data
student_data.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# Combine the both data into a single dataset.  
school_data_complete_df = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# To hold all the results
my_dict = {}

# %%
# Determine total number of schools 
totalschool= school_data['school_name'].count()
totalschool
my_dict['Total School']=totalschool

# %%
# total number of students
totalstudents = school_data_complete_df['student_name'].count()
my_dict['Total Students']=totalstudents

# %%
# total budget
totalbudget= school_data['budget'].sum()
my_dict['Total Budget'] = totalbudget

# %%
# calculate avearge math scores
avgmaths = school_data_complete_df['math_score'].mean()
my_dict['Average Math Score'] = avgmaths

# %%
# calculate avearge reading scores
avgreading = school_data_complete_df['reading_score'].mean()
my_dict['Average Reading Score'] = avgreading

# %%
# Determine overall passing Reading and Math in all schools
tot =school_data_complete_df['Student ID'].count()
print(tot)
# Out:
# 39170

# %%
overallpassing= (school_data_complete_df.loc[(school_data_complete_df['reading_score']>=70)&(school_data_complete_df['math_score']>=70)]['Student ID'].count()/tot)*100
overallpassing
my_dict['% Overall Passing'] = overallpassing
print(overallpassing)
# Out:
# 65.17232575950983

# %%
my_dict

# %%
#to reorder use this
results_df = pd.DataFrame([my_dict])
results_df = results_df[['Total School','Total Students', 'Total Budget', 'Average Math Score', 'Average Reading Score', '% Passing Math', '% Passing Reading', '% Overall Passing']]
results_df
# Out:
#    Total School  Total Students  Total Budget  Average Math Score  \
# 0            15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
# calculate percentage of students scoring 70 or more in maths 
passingmath= school_data_complete_df[school_data_complete_df['math_score']>=70]
passingmath
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# ...

# %%
studentsmath=passingmath['student_name'].count()

# %%
percentmath = (studentsmath/totalstudents)*100
print(percentmath)
my_dict['% Passing Math'] = percentmath
# Out:
# 74.9808526933878

# %%
# determine percentage students scoring 70 or more in reading
passingreading= school_data_complete_df[school_data_complete_df['reading_score']>=70]

# %%
studentsreading=passingreading['student_name'].count()

# %%
percentreading= (studentsreading/totalstudents)*100
print(percentreading)
my_dict['% Passing Reading'] = percentreading
# Out:
# 85.80546336482001

# %%
# School Summary

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# Extracting and keeping relevant columns
school_summary = school_data_complete_df[["school_name", "reading_score", "math_score", "size", "type", "budget"]]

# %%
school_summary.head()
# Out:
#          school_name  reading_score  math_score  size      type   budget
# 0  Huang High School             66          79  2917  District  1910635
# 1  Huang High School             94          61  2917  District  1910635
# 2  Huang High School             90          60  2917  District  1910635
# 3  Huang High School             67          58  2917  District  1910635
# 4  Huang High School             97          84  2917  District  1910635

# %%
school_group = school_summary.groupby(["school_name", "type"])
school_metrics = school_group.mean()
school_metrics
# Out:
#                                 reading_score  math_score    size     budget
# school_name           type
# Bailey High School    District      81.033963   77.048432  4976.0  3124928.0
# Cabrera High School   Charter       83.975780   83.061895  1858.0  1081356.0
# Figueroa High School  District      81.158020   76.711767  2949.0  1884411.0
# Ford High School      District      80.746258   77.102592  2739.0  1763916.0
# Griffin High School   Charter       83.816757   83.351499  1468.0   917500.0
# Hernandez High School District      80.934412   77.289752  4635.0  3022020.0
# Holden High School    Charter       83.814988   83.803279   427.0   248087.0
# Huang High School     District      81.182722   76.629414  2917.0  1910635.0
# Johnson High School   District      80.966394   77.072464  4761.0  3094650.0
# Pena High School      Charter       84.044699   83.839917   962.0   585858.0
# Rodriguez High School District      80.744686   76.842711  3999.0  2547363.0
# ...

# %%
#Determine school budget and add as a new column
school_metrics['Student Budget'] = school_metrics['budget']/school_metrics['size']
school_metrics
# Out:
#                                 reading_score  math_score    size     budget  \
# school_name           type
# Bailey High School    District      81.033963   77.048432  4976.0  3124928.0
# Cabrera High School   Charter       83.975780   83.061895  1858.0  1081356.0
# Figueroa High School  District      81.158020   76.711767  2949.0  1884411.0
# Ford High School      District      80.746258   77.102592  2739.0  1763916.0
# Griffin High School   Charter       83.816757   83.351499  1468.0   917500.0
# Hernandez High School District      80.934412   77.289752  4635.0  3022020.0
# Holden High School    Charter       83.814988   83.803279   427.0   248087.0
# Huang High School     District      81.182722   76.629414  2917.0  1910635.0
# Johnson High School   District      80.966394   77.072464  4761.0  3094650.0
# Pena High School      Charter       84.044699   83.839917   962.0   585858.0
# Rodriguez High School District      80.744686   76.842711  3999.0  2547363.0
# ...

# %%
# Determine % percent passing math in each school
# calculate students scoring more than 70% in math
#extracting relevant columns
new_school_summary = student_data[["Student ID","grade", "school_name", "reading_score", "math_score"]]
new_school_summary

# %%
# Determine overall passing Reading and Math in all schools

#new_school_group = new_school_summary.groupby(["school_name"])

# %%
# Determine overall passing Reading and Math in all schools
passing_math_and_reading = school_data_complete_df[(school_data_complete_df["reading_score"] >= 70)
                                               & (school_data_complete_df["math_score"] >= 70)]
passing_math_and_reading
# Out:
#        Student ID     student_name gender grade         school_name  \
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# 9               9   Matthew Greene      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 4                 97          84          0  District  2917  1910635
# ...

# %%
sch_overall = passing_math_and_reading.groupby(["school_name"]).count()["student_name"]
sch_overall
# Out:
# school_name
# Bailey High School       2719
# Cabrera High School      1697
# Figueroa High School     1569
# Ford High School         1487
# Griffin High School      1330
# Hernandez High School    2481
# Holden High School        381
# Huang High School        1561
# Johnson High School      2549
# Pena High School          871
# Rodriguez High School    2119
# Shelton High School      1583
# Thomas High School       1487
# Wilson High School       2068
# Wright High School       1626
# Name: student_name, dtype: int64

# %%
per_school_counts = school_data_complete_df["school_name"].value_counts()
per_school_counts
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: school_name, dtype: int64

# %%
schoolpercent=[(sch_overall)/(per_school_counts)]
school_percent
# Out:
# [[Bailey High School       0.546423
#   Cabrera High School      0.913348
#   Figueroa High School     0.532045
#   Ford High School         0.542899
#   Griffin High School      0.905995
#   Hernandez High School    0.535275
#   Holden High School       0.892272
#   Huang High School        0.535139
#   Johnson High School      0.535392
#   Pena High School         0.905405
#   Rodriguez High School    0.529882
#   Shelton High School      0.898921
#   Thomas High School       0.909480
#   Wilson High School       0.905826
#   Wright High School       0.903333
#   dtype: float64],
#  [Bailey High School       0.546423
#   Cabrera High School      0.913348
#   Figueroa High School     0.532045
#   Ford High School         0.542899
#   Griffin High School      0.905995
#   Hernandez High School    0.535275
#   Holden High School       0.892272
#   Huang High School        0.535139
#   Johnson High School      0.535392
#   Pena High School         0.905405
# ...

# %%
#stu_math_read = (new_school_group.loc[(new_school_group['t ID'].count()/tot)*100
passing_math = school_data_complete_df[(school_data_complete_df["math_score"] >= 70)]
passing_math
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# ...

# %%
sch_overall_math = passing_math.groupby(["school_name"]).count()["student_name"]
sch_overall_math
# Out:
# school_name
# Bailey High School       3318
# Cabrera High School      1749
# Figueroa High School     1946
# Ford High School         1871
# Griffin High School      1371
# Hernandez High School    3094
# Holden High School        395
# Huang High School        1916
# Johnson High School      3145
# Pena High School          910
# Rodriguez High School    2654
# Shelton High School      1653
# Thomas High School       1525
# Wilson High School       2143
# Wright High School       1680
# Name: student_name, dtype: int64

# %%
#schpassmath= schoolmath['math_score'].count()
per_school_math=[(sch_overall_math)/(per_school_counts)]
per_school_math
# Out:
# [Bailey High School       0.666801
#  Cabrera High School      0.941335
#  Figueroa High School     0.659885
#  Ford High School         0.683096
#  Griffin High School      0.933924
#  Hernandez High School    0.667530
#  Holden High School       0.925059
#  Huang High School        0.656839
#  Johnson High School      0.660576
#  Pena High School         0.945946
#  Rodriguez High School    0.663666
#  Shelton High School      0.938671
#  Thomas High School       0.932722
#  Wilson High School       0.938677
#  Wright High School       0.933333
#  dtype: float64]

# %%
passing_read = school_data_complete_df[(school_data_complete_df["reading_score"] >= 70)]
passing_read
# Out:
#        Student ID     student_name gender grade         school_name  \
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 1                 94          61          0  District  2917  1910635
# ...

# %%
sch_overall_read = passing_read.groupby(["school_name"]).count()["student_name"]
sch_overall_read
# Out:
# school_name
# Bailey High School       4077
# Cabrera High School      1803
# Figueroa High School     2381
# Ford High School         2172
# Griffin High School      1426
# Hernandez High School    3748
# Holden High School        411
# Huang High School        2372
# Johnson High School      3867
# Pena High School          923
# Rodriguez High School    3208
# Shelton High School      1688
# Thomas High School       1591
# Wilson High School       2204
# Wright High School       1739
# Name: student_name, dtype: int64

# %%
per_school_read=[(sch_overall_read)/(per_school_counts)]
per_school_read
# Out:
# [Bailey High School       0.819333
#  Cabrera High School      0.970398
#  Figueroa High School     0.807392
#  Ford High School         0.792990
#  Griffin High School      0.971390
#  Hernandez High School    0.808630
#  Holden High School       0.962529
#  Huang High School        0.813164
#  Johnson High School      0.812224
#  Pena High School         0.959459
#  Rodriguez High School    0.802201
#  Shelton High School      0.958546
#  Thomas High School       0.973089
#  Wilson High School       0.965396
#  Wright High School       0.966111
#  dtype: float64]

# %%
#Total_Students=schoolmath['size'].count()
#Total_Students

# %%
#schoolmath['%Passing Math'] = (schoolmath['math_score']/schoolmath['size'])*100
#schoolmath

# %%
#percentmath = (studentsmath/totalstudents)*100

# %%
# Use pandas sum() method to get the sum for each row

# Budget_df['Total School Budget'] = school_metrics.iloc[:, 2:].sum(axis=1)
# student_size = school_metrics['size'].count()
# per_stu_budget = (Budget/student_size)

# per_stu_budget = school_metrics.sum

# %% [markdown]
# # Determine per student budget
# school_metric

# %% [markdown]
# # Determine per student budget
# school_metric[student_budget] = school_metric.mean(axis=6)

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
